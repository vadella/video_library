# %%
# %load_ext autoreload

# %%
# %autoreload 2
from video_bibliotheek.video_info import MkvFile

# %%
from pathlib import Path

# %%
data_dir = Path('data')
filename = data_dir.joinpath('Blackadder - S01E01 - The Foretelling.mkv')

# %%
MkvFile(filename=filename)
# Out:
# eng
# dut
# data\Blackadder - S01E01 - The Foretelling.mkv
#             video: 0:33:31, 0.9 GB, [('h264, (720 x 592)',)]
#             audio: [('ac3, 2ch, stereo, 256kb/s',)]
#             sub: [('eng',), ('dut',)]

# %%
video_dir = Path(r'Y:\\')
mkv_files = video_dir.glob('**/*.mkv')

# %%
for mkv_file in mkv_files:
    print(mkv_file)
    print(MkvFile(mkv_file))
# Out:
# Y:\West Side Story (1961)\West Side Story (1961).mkv
# Y:\West Side Story (1961)\West Side Story (1961).mkv
#             video: 2:52:55, 13.3 GB, [('h264, (1920 x 880)',)]
#             audio: [('dts, 6ch, 5.1(side), 1536kb/s',), ('aac, 2ch, stereo, -1kb/s',)]
#             sub: [('unknown_lang, 2:52:55',), ('unknown_lang, 2:52:55',)]
# Y:\3 -10 to Yuma (2007)\3 -10 to Yuma (2007).mkv
# Y:\3 -10 to Yuma (2007)\3 -10 to Yuma (2007).mkv
#             video: 1:57:21, 1.8 GB, [('h264, (720 x 432)',)]
#             audio: [('dts, 6ch, 5.1(side), 768kb/s',), ('ac3, 2ch, stereo, 224kb/s',)]
#             sub: [('dut, 1:57:21',)]
# Y:\Ben-Hur (1959)\Ben-Hur (1959).mkv
# Y:\Ben-Hur (1959)\Ben-Hur (1959).mkv
#             video: 3:33:21, 3.6 GB, [('h264, (720 x 376)',)]
#             audio: [('ac3, 6ch, 5.1(side), 384kb/s',), ('aac, 2ch, stereo, -1kb/s',)]
#             sub: [('eng, 3:33:21',), ('dut, 3:33:21',)]
# Y:\Ben-Hur (1959)\Ben Hur-disc2.mkv
# Y:\Ben-Hur (1959)\Ben Hur-disc2.mkv
# ...

# %%
filename = Path('Y:\Walk the Line (2005)\Walk the Line (2005).mkv')

# %%
MkvFile(filename=filename)
# Out:
# Y:\Walk the Line (2005)\Walk the Line (2005).mkv
#             video: 2:10:18, 1.9 GB, [('h264, (720 x 416)',)]
#             audio: [('dts, 6ch, 5.1(side), 768kb/s',), ('ac3, 2ch, stereo, 224kb/s',)]
#             sub: [('eng',), ('dut',), ('dut',)]

# %%
import sqlalchemy
sqlalchemy.__version__
# Out:
# '1.1.11'

# %%
import datetime

# %%
 datetime.time(0)
# Out:
# datetime.time(0, 0)
